# %% [markdown]
# <a href="https://colab.research.google.com/github/rnalin/4aImersaoDados/blob/master/4thDataImersion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ANÁLISE DE IMÓVEIS DA CIDADE DE SÃO PAULO**
#
#
# ---

# %% [markdown]
# ![image-4288277141.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd

# %%
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head() # print the first 5 rows of the table.
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %% [markdown]
# ## **DIA 1**

# %%
dados.sample(10) # print ten random rows
# Out:
#                                                 Rua  \
# 3814                          Rua Augusto de Toledo
# 1537                            Rua Laerte Assunção
# 74                                Rua Caetano Braga
# 945   Rua Doutor Manuel Carlos de Figueiredo Ferraz
# 930                                 Rua Campo Verde
# 8164                         Avenida Amarilis, 933
# 2434                      Rua Xavier da Veiga, 109
# 3190                                            NaN
# 9820                                            NaN
# 2799                                            NaN
#
#                                    Bairro     Cidade  Metragem  Quartos  \
# 3814                              Cambuci  São Paulo       150        3
# 1537                    Jardim Paulistano  São Paulo       450        4
# 74    Conjunto Residencial José Bonifácio  São Paulo       129        3
# 945                        Jardim Morumbi  São Paulo      1200        5
# ...

# %%
dados.info() # show up some info about the data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
tem_imoveis_jardim_paulista = ( dados["Bairro"] == "Jardim Paulista")
tem_imoveis_jardim_paulista
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
sum(tem_imoveis_jardim_paulista )
# Out:
# 309

# %%
imoveis_jardim_paulista = dados[tem_imoveis_jardim_paulista]
imoveis_jardim_paulista
# Out:
#                             Rua           Bairro     Cidade  Metragem  \
# 68    Rua General Fonseca Teles  Jardim Paulista  São Paulo       420
# 98      Rua Marechal Bitencourt  Jardim Paulista  São Paulo       360
# 108                         NaN  Jardim Paulista  São Paulo      1060
# 112           Rua José Clemente  Jardim Paulista  São Paulo       724
# 134           Rua José Clemente  Jardim Paulista  São Paulo       700
# ...                         ...              ...        ...       ...
# 9388      Rua José Maria Lisboa  Jardim Paulista  São Paulo       160
# 9409    Rua Teixeira Pinto, 49   Jardim Paulista  São Paulo       360
# 9543       Rua Colatino Marques  Jardim Paulista  São Paulo       305
# 9549                        NaN  Jardim Paulista  São Paulo       420
# 9882                        NaN  Jardim Paulista  São Paulo       575
#
#       Quartos  Banheiros  Vagas                                 Valor
# ...

# %%
imoveis_jardim_paulista["Metragem"].mean()
# Out:
# 486.2977346278317

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()

# %%
n_imoveis_bairro.head(10).plot.bar()

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %% [markdown]
# Desafio 1

# %%
media_metragem_bairro = dados.groupby("Bairro").mean()["Metragem"]
media_metragem_bairro.sample(10)
# Out:
# Bairro
# Vila São Francisco (Zona Sul)       129.750000
# Vila Gea                            177.250000
# Jardim Bandeirantes (Zona Norte)    455.000000
# Jardim Danfer                       196.000000
# Vila Irmãos Arnoni                  358.750000
# Jardim Peri                         332.083333
# Jardim Pirituba                      63.000000
# Belenzinho                          215.692308
# Jaguaré                             210.000000
# Super Quadra Morumbi                256.000000
# Name: Metragem, dtype: float64

# %% [markdown]
# Desafio 2

# %%
bairro = dados["Bairro"] #1
bairro.head(5)
# Out:
# 0     Planalto Paulista
# 1    Jardim dos Estados
# 2       Jardim Reimberg
# 3        Jardim Morumbi
# 4                 Mooca
# Name: Bairro, dtype: object

# %%
bairro = dados.Bairro #2
bairro.head(5)
# Out:
# 0     Planalto Paulista
# 1    Jardim dos Estados
# 2       Jardim Reimberg
# 3        Jardim Morumbi
# 4                 Mooca
# Name: Bairro, dtype: object

# %%
bairro = pd.Series(dados["Bairro"]) #3
bairro.head(5)
# Out:
# 0     Planalto Paulista
# 1    Jardim dos Estados
# 2       Jardim Reimberg
# 3        Jardim Morumbi
# 4                 Mooca
# Name: Bairro, dtype: object

# %%
bairro = dados.iloc[:, 1:2] #4
bairro.head(5)
# Out:
#                Bairro
# 0   Planalto Paulista
# 1  Jardim dos Estados
# 2     Jardim Reimberg
# 3      Jardim Morumbi
# 4               Mooca

# %% [markdown]
# Desafio 3

# %%
#1

# %%
df=pd.DataFrame(dados,columns=["Bairro","Quartos","Vagas","Banheiros",])
df.head(10)
# Out:
#                Bairro  Quartos  Vagas  Banheiros
# 0   Planalto Paulista        4      6          8
# 1  Jardim dos Estados        4      4          4
# 2     Jardim Reimberg        4      2          3
# 3      Jardim Morumbi        3      4          2
# 4               Mooca        3      2          2
# 5         Santo Amaro        4      6          4
# 6   Cidade Mãe do Céu        4      2          4
# 7    Jardim Vergueiro        2      2          2
# 8      Jardim Benfica        2      1          1
# 9         Vila Alpina        3      2          3

# %%
media_comodos_bairro = df.groupby("Bairro").mean()
media_comodos_bairro.head(10)
# Out:
#                             Quartos      Vagas  Banheiros
# Bairro
# Aclimação                  3.318182   2.909091   3.079545
# Alto da Boa Vista          4.125000   4.625000   5.125000
# Alto da Lapa               3.151163   3.906977   3.790698
# Alto da Mooca              3.300000   3.650000   2.600000
# Alto de Pinheiros          3.938875   5.004890   4.838631
# Aricanduva                 3.000000   2.000000   3.000000
# Balneário Mar Paulista     4.000000  10.000000   4.000000
# Barra Funda                2.500000   1.388889   2.388889
# Barro Branco (Zona Norte)  3.500000   5.000000   4.000000
# Bela Aliança               3.333333   4.285714   4.238095

# %%
media_comodos_bairro.head(10).plot.barh()

# %%
#2

# %%
df = pd.DataFrame(dados, columns=["Bairro","Metragem", "Quartos", "Banheiros"])
df.head(10)
# Out:
#                Bairro  Metragem  Quartos  Banheiros
# 0   Planalto Paulista      1000        4          8
# 1  Jardim dos Estados       496        4          4
# 2     Jardim Reimberg       125        4          3
# 3      Jardim Morumbi       310        3          2
# 4               Mooca       100        3          2
# 5         Santo Amaro       440        4          4
# 6   Cidade Mãe do Céu       145        4          4
# 7    Jardim Vergueiro       150        2          2
# 8      Jardim Benfica        48        2          1
# 9         Vila Alpina       114        3          3

# %%
media_metragem_comodos = df.groupby("Bairro").mean()/10
media_metragem_comodos.head(10)
# Out:
#                             Metragem   Quartos  Banheiros
# Bairro
# Aclimação                  25.305682  0.331818   0.307955
# Alto da Boa Vista          41.887500  0.412500   0.512500
# Alto da Lapa               29.433721  0.315116   0.379070
# Alto da Mooca              27.005000  0.330000   0.260000
# Alto de Pinheiros          43.344499  0.393888   0.483863
# Aricanduva                 27.800000  0.300000   0.300000
# Balneário Mar Paulista     25.000000  0.400000   0.400000
# Barra Funda                13.544444  0.250000   0.238889
# Barro Branco (Zona Norte)  48.900000  0.350000   0.400000
# Bela Aliança               34.547619  0.333333   0.423810

# %%
media_metragem_comodos.sort_values("Metragem").head(20)
# Out:
#                                     Metragem   Quartos  Banheiros
# Bairro
# Vila Guaca                          1.000000  0.300000        0.2
# Vila Leonor                         4.600000  0.200000        0.2
# Jardim Benfica                      4.800000  0.200000        0.1
# Jardim Nova Germania                5.700000  0.300000        0.1
# Cidade Antônio Estevão de Carvalho  5.750000  0.200000        0.1
# Jardim São José                     6.200000  0.100000        0.1
# Jardim São Jorge (Raposo Tavares)   6.200000  0.200000        0.1
# Vila Carmosina                      6.300000  0.200000        0.2
# Jardim Pirituba                     6.300000  0.200000        0.3
# Vila Reis                           6.600000  0.200000        0.1
# Jardim Felicidade (Zona Oeste)      7.000000  0.300000        0.1
# Vila Conde do Pinhal                7.000000  0.200000        0.2
# Jardim São Jorge                    7.500000  0.200000        0.1
# ...

# %%
media_metragem_comodos.sort_values("Metragem").head(10).plot.barh()

# %% [markdown]
# Desafio 4

# %%
data = pd.DataFrame(dados, columns = ["Bairro", "Metragem"])
por_bairro = data.groupby("Bairro").mean()

df = pd.DataFrame(por_bairro)
df.head(5)
# Out:
#                      Metragem
# Bairro
# Aclimação          253.056818
# Alto da Boa Vista  418.875000
# Alto da Lapa       294.337209
# Alto da Mooca      270.050000
# Alto de Pinheiros  433.444988

# %%
mediana = data.groupby("Bairro").median()
min = data.groupby("Bairro").min()
max = data.groupby("Bairro").max()
qtd = data.groupby("Bairro").count()
df.insert(1, "Mediana", mediana)
df.insert(2, "Mín", min)
df.insert(3, "Máx", max)
df.insert(4, "Qtd", qtd)

# %%
df
# Out:
#                      Metragem  Mediana  Mín   Máx  Qtd
# Bairro
# Aclimação          253.056818    227.5  104  1500   88
# Alto da Boa Vista  418.875000    378.0  315   595    8
# Alto da Lapa       294.337209    255.0   46  1133   86
# Alto da Mooca      270.050000    182.5   84   805   20
# Alto de Pinheiros  433.444988    412.0  100  1530  409
# ...                       ...      ...  ...   ...  ...
# Vila Água Funda    152.200000    143.0   90   200    5
# Água Branca        191.000000    174.0   91   400   13
# Água Fria          165.416667    174.5   60   314   12
# Água Funda         139.000000    139.0  125   153    2
# Água Rasa          340.250000    180.0   86   805    8
#
# [701 rows x 5 columns]

# %%
df.head(5).plot.pie
# Out:
# <bound method PlotAccessor.pie of <pandas.plotting._core.PlotAccessor object at 0x7f5e8fd05c50>>

# %% [markdown]
# Desafio 5

# %%
sem_rua = dados.isnull()['Rua']
por_bairro = dados[sem_rua].Bairro.value_counts()
por_bairro
# Out:
# Jardim Guedala                      190
# Alto de Pinheiros                   169
# Jardim Paulista                     138
# Jardim Europa                       128
# Jardim Leonor                       118
#                                    ...
# Jardim do Colégio (Zona Norte)        1
# Alto da Boa Vista                     1
# Jardim Aeroporto                      1
# Conjunto Residencial Vista Verde      1
# Jardim Santo Elias                    1
# Name: Bairro, Length: 394, dtype: int64

# %%
por_bairro.head(5).plot.pie()

# %% [markdown]
# ---

# %% [markdown]
# ## **DIA 2**

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados.Valor[0]
# Out:
# 'R$ 7.000.000'

# %%
dados.Valor[0].split()
# Out:
# ['R$', '7.000.000']

# %%
dados.Valor.str.split(expand=True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
len(dados.Valor.str.split(expand=True)[1].unique())
# Out:
# 1038

# %%
dados.Valor.str.split(expand=True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %%
dados[["Moeda", "Valor_anuncio", "Tipo_anuncio"]] = dados["Valor"].str.split(expand = True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %%
dados[dados['Tipo_anuncio'].isnull()]['Tipo_anuncio'].unique()
# Out:
# array([None], dtype=object)

# %%
dados_vendas = dados[dados["Tipo_anuncio"].isnull()]
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# ...

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   object
#  10  Tipo_anuncio   0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %%
dados_vendas['Valor_anuncio'] = dados_vendas['Valor_anuncio'].str.replace('.', '').astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_vendas.Valor_anuncio.plot.hist()

# %%
pd.set_option("display.precision", 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio
# count   9156.00  9156.00    9156.00 9156.00        9156.00
# mean     434.42     3.45       3.80    3.96     3052202.96
# std     7856.42     1.05       1.97    2.60     3944208.19
# min       10.00     1.00       1.00    1.00       13000.00
# 25%      168.00     3.00       2.00    2.00      890000.00
# 50%      276.00     3.00       4.00    4.00     1800000.00
# 75%      450.00     4.00       5.00    5.00     3500000.00
# max   750000.00    16.00      40.00   50.00    65000000.00

# %%
dados_vendas[["Rua", "Bairro", "Cidade"]].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set()
plt.figure(figsize=(10, 8))

# %%
ax = sns.histplot(data = dados_vendas, x = "Valor_anuncio", kde = True)
ax.set_title("Histograma Valor Imóvel")
plt.xlim((-50, 10000000))
plt.show()

# %% [markdown]
# ## **Desafio Aula 2**
# Criar uma escala de valores em milhões
#
# 1. Deixar o gráfico do histograma de valores legível (alterar labels, cores,
# título, escala)
# 2. Preço do metro quadrado por bairro e plotar em um gráfico ideal
# 3. Explorar as bibliotecas de visualizações e colocar as suas conclusão
# 4. Pesquisar um visualização para analisar os quartis, mediana e outliers

# %% [markdown]
# Desafio 1

# %%
dados_vendas.loc[:,("Valor_milhoes")]= dados_vendas.Valor_anuncio / 1000000
dados_vendas.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio  Valor_milhoes
# count   9156.00  9156.00    9156.00 9156.00        9156.00        9156.00
# mean     434.42     3.45       3.80    3.96     3052202.96           3.05
# std     7856.42     1.05       1.97    2.60     3944208.19           3.94
# min       10.00     1.00       1.00    1.00       13000.00           0.01
# 25%      168.00     3.00       2.00    2.00      890000.00           0.89
# 50%      276.00     3.00       4.00    4.00     1800000.00           1.80
# 75%      450.00     4.00       5.00    5.00     3500000.00           3.50
# ...

# %% [markdown]
# Desafio 2

# %%
sns.set()
plt.figure(figsize=(10,8))
ax = sns.histplot(data = dados_vendas, x='Valor_milhoes', bins=250, kde=True, color='#000fff', hue_norm=True)
ax.set_title('Histograma Valor Imóvel')
ax.set_xlabel('Valor dos Imóveis em Milhões')
ax.set_ylabel('Nº de Imóveis')
plt.xlim(-0.05, 10.2)
plt.xticks(list(range(0,11)))
plt.show()

# %% [markdown]
# Desafio 3

# %%
dados_vendas['Valor_m2'] = dados_vendas['Valor_anuncio']/dados_vendas['Metragem']
dados_vendas.groupby('Bairro').mean() # Transforma o bairro em index e pega apenas as colunas de valores possíveis de se usar média
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio  \
# Bairro
# Aclimação            246.16     3.27       3.04   2.91     1763200.01
# Alto da Boa Vista    418.88     4.12       5.12   4.62     2391250.00
# Alto da Lapa         299.25     3.15       3.85   4.00     2083168.75
# Alto da Mooca        270.05     3.30       2.60   3.65     1184170.00
# Alto de Pinheiros    429.85     3.94       4.83   4.95     4782698.96
# ...                     ...      ...        ...    ...            ...
# Vila Água Funda      152.20     2.60       2.20   2.60      652000.00
# ...

# %%
dados_bairro = dados_vendas.groupby('Bairro').sum()
dados_bairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio  \
# Bairro
# Aclimação             19447      258        240    230   139292801.00
# Alto da Boa Vista      3351       33         41     37    19130000.00
# Alto da Lapa          23940      252        308    320   166653500.00
# Alto da Mooca          5401       66         52     73    23683400.00
# Alto de Pinheiros    158616     1453       1782   1827  1764815915.00
# ...                     ...      ...        ...    ...            ...
# Vila Água Funda         761       13         11     13     3260000.00
# Água Branca            2083       37         39     27    14718000.00
# Água Fria              1985       34         41     30    11125000.00
# Água Funda              278        6          5      4     1090000.00
# Água Rasa              1117       16         12     22     4297000.00
#
#                    Valor_milhoes   Valor_m2
# Bairro
# Aclimação                 139.29  604837.39
# ...

# %%
dados_bairro['Valor_m2_bairro'] = dados_bairro['Valor_anuncio']/dados_bairro['Metragem']
dados_bairro
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  Valor_anuncio  \
# 0            Aclimação     19447      258        240    230   139292801.00
# 1    Alto da Boa Vista      3351       33         41     37    19130000.00
# 2         Alto da Lapa     23940      252        308    320   166653500.00
# 3        Alto da Mooca      5401       66         52     73    23683400.00
# 4    Alto de Pinheiros    158616     1453       1782   1827  1764815915.00
# ..                 ...       ...      ...        ...    ...            ...
# 692    Vila Água Funda       761       13         11     13     3260000.00
# 693        Água Branca      2083       37         39     27    14718000.00
# 694          Água Fria      1985       34         41     30    11125000.00
# 695         Água Funda       278        6          5      4     1090000.00
# 696          Água Rasa      1117       16         12     22     4297000.00
#
#      Valor_milhoes   Valor_m2  Valor_m2_bairro
# ...

# %%
top_bairros = dados_vendas['Bairro'].value_counts()[:10].index
# Resetando o grafico para o bairro não ser lido como index
dados_bairro.reset_index(inplace = True)
dados_bairro
# Out:
#      index             Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 0        0          Aclimação     19447      258        240    230
# 1        1  Alto da Boa Vista      3351       33         41     37
# 2        2       Alto da Lapa     23940      252        308    320
# 3        3      Alto da Mooca      5401       66         52     73
# 4        4  Alto de Pinheiros    158616     1453       1782   1827
# ..     ...                ...       ...      ...        ...    ...
# 692    692    Vila Água Funda       761       13         11     13
# 693    693        Água Branca      2083       37         39     27
# 694    694          Água Fria      1985       34         41     30
# 695    695         Água Funda       278        6          5      4
# 696    696          Água Rasa      1117       16         12     22
#
#      Valor_anuncio  Valor_milhoes   Valor_m2  Valor_m2_bairro
# 0     139292801.00         139.29  604837.39          7162.69
# ...

# %%
# Criando uma query com os top 10 bairros
dados_bairro.query('Bairro in @top_bairros')
# Out:
#      index             Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 4        4  Alto de Pinheiros    158616     1453       1782   1827
# 19      19  Brooklin Paulista     70002      778        862    832
# 57      57      Cidade Jardim    132220      789       1008   1172
# 155    155      Jardim Europa    118898      795        993   1056
# 168    168     Jardim Guedala    972212     1443       2027   2161
# 187    187      Jardim Leonor     97141      697        941    902
# 227    227    Jardim Paulista    130283     1028       1231   1171
# 338    338           Pacaembu    100285      774        889   1028
# 396    396  Planalto Paulista     59250      636        768    713
# 564    564      Vila Madalena     66250      739        786    712
#
#      Valor_anuncio  Valor_milhoes   Valor_m2  Valor_m2_bairro
# 4    1764815915.00        1764.82 4158622.61         11126.34
# 19    475796789.00         475.80 1627341.87          6796.90
# ...

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x='Bairro', y='Valor_m2_bairro', data=dados_bairro.query('Bairro in @top_bairros'))
ax.tick_params(axis='x', rotation=45)

# %% [markdown]
# Desafio 4

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(data = dados_vendas.query('Bairro in @top_bairros'), x='Bairro', y='Valor_anuncio')
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
# Criando gráfico de boxplot sobre o valor da metragem por bairro eliminando os outliers
plt.figure(figsize=(10,8))
ax = sns.boxplot(data = dados_vendas.query('Bairro in @top_bairros and Metragem < 30000'), x='Bairro', y='Metragem')
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
# Criando gráfico de boxplot para análisar os quartis, mediana e outliers das vagas.
plt.figure(figsize=(8, 12))
ax = sns.boxplot(y = 'Vagas',data = dados_vendas, color='green')
ax.set_title("Distribuicao das Vagas")
ax.set_xlabel("Vagas")
ax.set_ylabel("Numero de Vagas")
plt.show()
